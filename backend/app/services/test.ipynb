# %%
from pathlib import Path
import pandas as pd
# RAW_DATA_DIR = Path("data/raw")
# PROCESSED_DATA_DIR = Path("data/processed")
# print(f"Raw data directory: {RAW_DATA_DIR}")
# print(f"Processed data directory: {PROCESSED_DATA_DIR}")

# MOVIE_RAW_PATH = RAW_DATA_DIR / "movies_metadata.csv"
# print(f"Movie raw data path: {MOVIE_RAW_PATH}")
PROJECT_ROOT = Path.cwd().parent.parent
print(f"Project root directory: {PROJECT_ROOT}")
MOVIE_RAW_PATH = PROJECT_ROOT / "data/raw/movies_metadata.csv"
print(f"Movie raw data path: {MOVIE_RAW_PATH}")
movies = pd.read_csv(MOVIE_RAW_PATH)
print(f"Movies DataFrame shape: {movies.shape}")
print(f"Movies DataFrame columns: {movies.columns.tolist()}")
# movies.head()
print(movies['id'].head())
# Out:
# Project root directory: d:\Personal Project Summer 2026\movie agent\backend
# Movie raw data path: d:\Personal Project Summer 2026\movie agent\backend\data\raw\movies_metadata.csv
# Movies DataFrame shape: (4803, 20)
# Movies DataFrame columns: ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']
# 0     19995
# 1       285
# 2    206647
# 3     49026
# 4     49529
# Name: id, dtype: int64
